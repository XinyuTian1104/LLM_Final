# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from captum.attr import IntegratedGradients
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
def prepare_input(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    return inputs

# %%
ig = IntegratedGradients(model)

# %%
from captum.attr import IntegratedGradients, LayerIntegratedGradients

def attribute_text(text):
    inputs = prepare_input(text)
    input_ids = inputs['input_ids'].long()
    attention_mask = inputs['attention_mask']
    
    # Define a forward function that isolates the input feature for attribution
    # The function outputs the logits
    def forward_func(input_ids, attention_mask):
        return model(input_ids=input_ids, attention_mask=attention_mask)[0]
    
    # Use LayerIntegratedGradients and target the embedding layer specifically
    lig = LayerIntegratedGradients(forward_func, model.bert.embeddings)
    
    # Calculate attributions with respect to the embeddings
    attributions, delta = lig.attribute(inputs=input_ids,
                                        additional_forward_args=(attention_mask,),
                                        target=1,
                                        return_convergence_delta=True,
                                        attribute_to_layer_input=False)  # attribute to the output of the embeddings

    return attributions

# %%
def visualize_attributions(text):
    inputs = prepare_input(text)
    attributions = attribute_text(text)
    tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
    
    # Summing across the embedding dimensions to get per-token attribution
    token_attributions = attributions.sum(dim=-1).squeeze(0).detach().numpy()
    
    # Display tokens with their attributions
    for token, attribution in zip(tokens, token_attributions):
        print(f"{token}: {attribution:.4f}")

# %%
text = "The movie was fantastic!"
visualize_attributions(text)
# Out:
# [CLS]: 0.0993
# the: 0.1091
# movie: -0.2246
# was: 0.1845
# fantastic: -0.1559
# !: -0.1775
# [SEP]: 0.1472

# %%
from transformers import LlamaModel, LlamaConfig

# Initializing a LLaMA llama-7b style configuration
configuration = LlamaConfig()

# Initializing a model from the llama-7b style configuration
model = LlamaModel(configuration)

# Accessing the model configuration
configuration = model.config

# %%
print(model)
# Out:
# LlamaModel(
#   (embed_tokens): Embedding(32000, 4096)
#   (layers): ModuleList(
#     (0-31): 32 x LlamaDecoderLayer(
#       (self_attn): LlamaSdpaAttention(
#         (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (mlp): LlamaMLP(
#         (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#         (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#         (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#         (act_fn): SiLU()
#       )
#       (input_layernorm): LlamaRMSNorm()
#       (post_attention_layernorm): LlamaRMSNorm()
#     )
#   )
#   (norm): LlamaRMSNorm()
# )

# %%
print(configuration)
# Out:
# LlamaConfig {
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 2048,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 10000.0,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 32000
# }

# %%
for (name, param) in model.named_parameters():
    print(f"{name}: {param}")
# Out:
# embed_tokens.weight: Parameter containing:
# tensor([[ 0.0098, -0.0053,  0.0223,  ..., -0.0305,  0.0012, -0.0400],
#         [-0.0235, -0.0234,  0.0160,  ..., -0.0098,  0.0154, -0.0212],
#         [-0.0028,  0.0105,  0.0304,  ..., -0.0012,  0.0159,  0.0208],
#         ...,
#         [-0.0308, -0.0031,  0.0051,  ...,  0.0130, -0.0019,  0.0044],
#         [ 0.0178,  0.0289,  0.0265,  ...,  0.0284,  0.0141, -0.0062],
#         [ 0.0164, -0.0250,  0.0042,  ...,  0.0049, -0.0098,  0.0230]],
#        requires_grad=True)
# layers.0.self_attn.q_proj.weight: Parameter containing:
# tensor([[ 0.0086, -0.0338, -0.0118,  ..., -0.0275,  0.0066, -0.0116],
#         [ 0.0220,  0.0044,  0.0054,  ..., -0.0156,  0.0096, -0.0001],
#         [-0.0169,  0.0348,  0.0461,  ...,  0.0090, -0.0023,  0.0116],
#         ...,
#         [-0.0313, -0.0087, -0.0020,  ...,  0.0030,  0.0120,  0.0145],
#         [ 0.0315,  0.0077,  0.0211,  ..., -0.0356, -0.0483, -0.0172],
#         [-0.0127, -0.0429, -0.0151,  ...,  0.0096, -0.0002, -0.0114]],
#        requires_grad=True)
# layers.0.self_attn.k_proj.weight: Parameter containing:
# tensor([[ 0.0108, -0.0029,  0.0118,  ..., -0.0003,  0.0283, -0.0040],
#         [ 0.0468, -0.0145,  0.0224,  ..., -0.0082,  0.0210, -0.0169],
#         [-0.0245,  0.0331, -0.0139,  ..., -0.0012,  0.0158, -0.0224],
#         ...,
#         [-0.0024,  0.0145,  0.0368,  ..., -0.0225,  0.0109,  0.0194],
#         [ 0.0385,  0.0112, -0.0096,  ...,  0.0009, -0.0118, -0.0123],
#         [-0.0182, -0.0022,  0.0061,  ..., -0.0058,  0.0077, -0.0433]],
#        requires_grad=True)
# layers.0.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 0.0005,  0.0036, -0.0141,  ...,  0.0119,  0.0471, -0.0066],
#         [-0.0106, -0.0063,  0.0037,  ..., -0.0045,  0.0021,  0.0298],
#         [-0.0163,  0.0078, -0.0103,  ...,  0.0273, -0.0031, -0.0074],
#         ...,
#         [-0.0232, -0.0278,  0.0284,  ...,  0.0113, -0.0105, -0.0056],
#         [-0.0041, -0.0220, -0.0214,  ..., -0.0084, -0.0021,  0.0028],
#         [-0.0395, -0.0163,  0.0405,  ..., -0.0019, -0.0100,  0.0153]],
#        requires_grad=True)
# layers.0.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 1.0552e-02,  1.5425e-05,  1.8388e-02,  ...,  2.3976e-03,
#           2.9055e-02, -4.2035e-02],
#         [-4.9827e-02, -4.4552e-03, -1.4313e-02,  ...,  6.0638e-03,
#           7.5265e-03, -2.2179e-02],
#         [-1.0041e-02,  1.6178e-02, -3.7690e-03,  ...,  6.5086e-03,
#           8.8694e-04, -3.1424e-02],
#         ...,
#         [-1.0929e-02,  5.5388e-02,  1.8034e-02,  ..., -1.5766e-02,
#           1.7331e-02, -5.1864e-02],
#         [ 3.4189e-02,  2.4385e-02,  1.9159e-02,  ...,  3.0521e-04,
#           1.9646e-02, -3.1800e-02],
#         [ 1.5863e-03,  8.2389e-03,  1.1574e-02,  ..., -2.6493e-03,
#           3.8226e-02,  1.0217e-02]], requires_grad=True)
# layers.0.mlp.gate_proj.weight: Parameter containing:
# tensor([[-0.0046,  0.0460, -0.0044,  ..., -0.0009,  0.0136,  0.0072],
#         [-0.0179, -0.0146,  0.0124,  ..., -0.0348, -0.0058,  0.0055],
#         [-0.0226, -0.0246, -0.0093,  ...,  0.0092,  0.0277, -0.0064],
#         ...,
#         [-0.0218,  0.0052, -0.0306,  ...,  0.0063,  0.0098,  0.0101],
#         [-0.0288,  0.0278,  0.0106,  ..., -0.0163,  0.0364, -0.0132],
#         [-0.0246, -0.0341, -0.0034,  ..., -0.0001,  0.0002,  0.0089]],
#        requires_grad=True)
# layers.0.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0236,  0.0162,  0.0031,  ..., -0.0467, -0.0205, -0.0076],
#         [ 0.0021, -0.0020, -0.0171,  ...,  0.0096,  0.0225,  0.0015],
#         [-0.0226,  0.0167,  0.0062,  ..., -0.0077, -0.0026, -0.0092],
#         ...,
#         [-0.0059,  0.0065,  0.0163,  ...,  0.0046,  0.0014, -0.0293],
#         [-0.0316,  0.0076, -0.0057,  ...,  0.0047,  0.0194, -0.0030],
#         [-0.0119,  0.0121, -0.0250,  ..., -0.0003, -0.0335,  0.0022]],
#        requires_grad=True)
# layers.0.mlp.down_proj.weight: Parameter containing:
# tensor([[-0.0189,  0.0049, -0.0171,  ...,  0.0086,  0.0063, -0.0164],
#         [-0.0049,  0.0282,  0.0371,  ..., -0.0119,  0.0029,  0.0187],
#         [ 0.0389,  0.0175, -0.0007,  ..., -0.0046, -0.0242, -0.0063],
#         ...,
#         [-0.0293, -0.0117,  0.0406,  ...,  0.0325,  0.0006, -0.0176],
#         [-0.0602,  0.0262, -0.0031,  ...,  0.0244, -0.0319, -0.0357],
#         [-0.0079, -0.0174,  0.0167,  ..., -0.0102, -0.0163, -0.0170]],
#        requires_grad=True)
# layers.0.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.0.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.1.self_attn.q_proj.weight: Parameter containing:
# tensor([[-0.0056, -0.0199, -0.0043,  ..., -0.0119, -0.0104, -0.0134],
#         [ 0.0078, -0.0156,  0.0097,  ..., -0.0122, -0.0094, -0.0281],
#         [-0.0404,  0.0127, -0.0044,  ..., -0.0012,  0.0293, -0.0304],
#         ...,
#         [-0.0118,  0.0138, -0.0102,  ..., -0.0162, -0.0119, -0.0083],
#         [-0.0200, -0.0024, -0.0182,  ...,  0.0030, -0.0189,  0.0098],
#         [ 0.0209, -0.0204, -0.0025,  ...,  0.0101, -0.0045,  0.0038]],
#        requires_grad=True)
# layers.1.self_attn.k_proj.weight: Parameter containing:
# tensor([[-0.0180, -0.0004,  0.0195,  ..., -0.0350,  0.0086, -0.0176],
#         [ 0.0202,  0.0049, -0.0175,  ..., -0.0080, -0.0127,  0.0027],
#         [-0.0155, -0.0239, -0.0183,  ..., -0.0082, -0.0026,  0.0163],
#         ...,
#         [ 0.0313,  0.0148, -0.0305,  ..., -0.0208, -0.0319, -0.0125],
#         [ 0.0007,  0.0074,  0.0121,  ..., -0.0566, -0.0107, -0.0354],
#         [ 0.0427,  0.0032, -0.0102,  ...,  0.0270, -0.0160,  0.0127]],
#        requires_grad=True)
# layers.1.self_attn.v_proj.weight: Parameter containing:
# tensor([[-0.0140,  0.0217,  0.0306,  ..., -0.0191,  0.0314, -0.0317],
#         [-0.0377, -0.0154,  0.0055,  ...,  0.0029,  0.0154, -0.0243],
#         [-0.0255, -0.0196, -0.0355,  ..., -0.0327, -0.0048, -0.0218],
#         ...,
#         [ 0.0106,  0.0072,  0.0349,  ..., -0.0171, -0.0238,  0.0221],
#         [ 0.0073,  0.0198,  0.0073,  ...,  0.0217,  0.0123, -0.0002],
#         [-0.0265, -0.0130, -0.0203,  ...,  0.0073,  0.0160,  0.0291]],
#        requires_grad=True)
# layers.1.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 0.0088,  0.0106,  0.0101,  ..., -0.0024, -0.0367,  0.0274],
#         [-0.0145, -0.0374, -0.0126,  ...,  0.0130,  0.0078,  0.0060],
#         [ 0.0253,  0.0016,  0.0015,  ...,  0.0340,  0.0058, -0.0306],
#         ...,
#         [-0.0249, -0.0124, -0.0435,  ...,  0.0207, -0.0034,  0.0337],
#         [-0.0044, -0.0030, -0.0316,  ..., -0.0107, -0.0041,  0.0466],
#         [-0.0042, -0.0080, -0.0005,  ..., -0.0091, -0.0006,  0.0093]],
#        requires_grad=True)
# layers.1.mlp.gate_proj.weight: Parameter containing:
# tensor([[-0.0047,  0.0021, -0.0227,  ..., -0.0071, -0.0159,  0.0248],
#         [ 0.0005, -0.0112, -0.0410,  ..., -0.0457,  0.0310,  0.0243],
#         [-0.0085,  0.0166, -0.0063,  ..., -0.0293,  0.0018, -0.0042],
#         ...,
#         [ 0.0180, -0.0144,  0.0180,  ..., -0.0041,  0.0137,  0.0208],
#         [-0.0237,  0.0141, -0.0368,  ..., -0.0375,  0.0040, -0.0308],
#         [ 0.0001,  0.0141,  0.0179,  ..., -0.0133,  0.0189,  0.0545]],
#        requires_grad=True)
# layers.1.mlp.up_proj.weight: Parameter containing:
# tensor([[ 1.4120e-02, -8.7111e-03,  2.4979e-02,  ...,  1.3924e-03,
#          -1.2561e-02, -4.3019e-02],
#         [ 4.0327e-02,  1.4944e-02,  8.2798e-03,  ...,  3.5590e-03,
#          -4.2027e-02, -6.4562e-04],
#         [ 4.5647e-03,  2.1367e-02, -2.3587e-02,  ..., -2.7845e-02,
#          -1.5598e-05, -3.5851e-03],
#         ...,
#         [ 7.2296e-03,  2.4875e-03,  2.9333e-02,  ..., -1.5492e-02,
#           3.9247e-03, -1.8962e-02],
#         [-2.1765e-02, -2.8338e-03,  2.2342e-02,  ..., -1.7379e-02,
#          -1.7719e-02, -1.1328e-02],
#         [-1.3487e-02, -1.8984e-02, -1.1276e-02,  ...,  1.6759e-02,
#           1.9151e-03, -1.8226e-02]], requires_grad=True)
# layers.1.mlp.down_proj.weight: Parameter containing:
# tensor([[ 0.0045,  0.0092,  0.0071,  ..., -0.0054, -0.0171,  0.0003],
#         [-0.0033,  0.0116, -0.0105,  ..., -0.0110, -0.0071,  0.0098],
#         [ 0.0039,  0.0069, -0.0154,  ..., -0.0006,  0.0069,  0.0146],
#         ...,
#         [ 0.0462,  0.0273,  0.0212,  ...,  0.0294, -0.0063, -0.0048],
#         [-0.0040,  0.0118, -0.0193,  ...,  0.0146, -0.0071,  0.0090],
#         [-0.0184, -0.0117, -0.0187,  ..., -0.0053,  0.0167,  0.0017]],
#        requires_grad=True)
# layers.1.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.1.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.2.self_attn.q_proj.weight: Parameter containing:
# tensor([[ 0.0212, -0.0091, -0.0272,  ...,  0.0137,  0.0163,  0.0237],
#         [-0.0213, -0.0209,  0.0023,  ...,  0.0365, -0.0152,  0.0538],
#         [-0.0184, -0.0013,  0.0023,  ..., -0.0267, -0.0367,  0.0163],
#         ...,
#         [-0.0286, -0.0152, -0.0027,  ..., -0.0091, -0.0203,  0.0030],
#         [ 0.0266,  0.0192, -0.0124,  ..., -0.0279,  0.0035, -0.0089],
#         [-0.0105,  0.0101,  0.0249,  ..., -0.0196, -0.0136, -0.0391]],
#        requires_grad=True)
# layers.2.self_attn.k_proj.weight: Parameter containing:
# tensor([[ 0.0011,  0.0092,  0.0016,  ..., -0.0162,  0.0103, -0.0298],
#         [ 0.0010, -0.0072,  0.0066,  ..., -0.0191,  0.0221,  0.0248],
#         [ 0.0121, -0.0299,  0.0149,  ...,  0.0211,  0.0116,  0.0048],
#         ...,
#         [-0.0211, -0.0123,  0.0179,  ...,  0.0225, -0.0037, -0.0185],
#         [-0.0172,  0.0578, -0.0031,  ..., -0.0127, -0.0251,  0.0112],
#         [ 0.0179, -0.0445,  0.0225,  ..., -0.0255,  0.0096,  0.0088]],
#        requires_grad=True)
# layers.2.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 0.0251,  0.0038,  0.0186,  ...,  0.0015,  0.0279,  0.0031],
#         [-0.0153, -0.0157, -0.0382,  ..., -0.0068,  0.0091, -0.0144],
#         [ 0.0152,  0.0041,  0.0288,  ...,  0.0096,  0.0241,  0.0157],
#         ...,
#         [ 0.0168, -0.0052,  0.0131,  ...,  0.0326, -0.0177,  0.0154],
#         [-0.0053, -0.0190,  0.0187,  ..., -0.0242,  0.0079, -0.0058],
#         [ 0.0120,  0.0002,  0.0122,  ...,  0.0069,  0.0148, -0.0223]],
#        requires_grad=True)
# layers.2.self_attn.o_proj.weight: Parameter containing:
# tensor([[-0.0164,  0.0189, -0.0256,  ...,  0.0020, -0.0230, -0.0128],
#         [-0.0154,  0.0184,  0.0165,  ..., -0.0033,  0.0008, -0.0221],
#         [-0.0099, -0.0290,  0.0029,  ..., -0.0162, -0.0175,  0.0014],
#         ...,
#         [ 0.0272,  0.0059, -0.0054,  ..., -0.0180,  0.0014, -0.0092],
#         [-0.0170,  0.0201,  0.0192,  ..., -0.0188,  0.0200,  0.0019],
#         [-0.0011, -0.0047, -0.0249,  ...,  0.0358,  0.0088,  0.0082]],
#        requires_grad=True)
# layers.2.mlp.gate_proj.weight: Parameter containing:
# tensor([[-0.0407, -0.0523, -0.0024,  ..., -0.0099, -0.0163, -0.0125],
#         [ 0.0125,  0.0168,  0.0531,  ..., -0.0142,  0.0330,  0.0050],
#         [ 0.0192,  0.0194, -0.0453,  ...,  0.0135,  0.0341, -0.0124],
#         ...,
#         [ 0.0161, -0.0380, -0.0023,  ...,  0.0093, -0.0023, -0.0152],
#         [-0.0251, -0.0025,  0.0045,  ...,  0.0264, -0.0371,  0.0339],
#         [-0.0065, -0.0040,  0.0061,  ...,  0.0151,  0.0150, -0.0090]],
#        requires_grad=True)
# layers.2.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0017, -0.0030, -0.0149,  ..., -0.0017,  0.0510,  0.0075],
#         [-0.0073, -0.0047, -0.0038,  ..., -0.0219,  0.0046,  0.0168],
#         [-0.0117, -0.0186,  0.0176,  ...,  0.0018,  0.0079,  0.0236],
#         ...,
#         [ 0.0172,  0.0049,  0.0227,  ...,  0.0006,  0.0058,  0.0061],
#         [ 0.0130,  0.0305, -0.0258,  ..., -0.0175,  0.0230,  0.0014],
#         [-0.0119, -0.0011,  0.0283,  ..., -0.0150, -0.0181,  0.0234]],
#        requires_grad=True)
# layers.2.mlp.down_proj.weight: Parameter containing:
# tensor([[-0.0317,  0.0129,  0.0148,  ...,  0.0054, -0.0045, -0.0190],
#         [-0.0489,  0.0122, -0.0144,  ..., -0.0386, -0.0303,  0.0234],
#         [ 0.0031, -0.0074,  0.0003,  ...,  0.0003,  0.0144, -0.0410],
#         ...,
#         [-0.0177, -0.0261,  0.0149,  ..., -0.0032,  0.0229,  0.0071],
#         [-0.0054,  0.0117, -0.0164,  ..., -0.0186, -0.0133,  0.0193],
#         [ 0.0113, -0.0246, -0.0240,  ..., -0.0096,  0.0075, -0.0278]],
#        requires_grad=True)
# layers.2.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.2.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.3.self_attn.q_proj.weight: Parameter containing:
# tensor([[-0.0235,  0.0043,  0.0042,  ...,  0.0090, -0.0154, -0.0019],
#         [ 0.0090,  0.0061,  0.0213,  ...,  0.0028,  0.0134, -0.0171],
#         [ 0.0005, -0.0494,  0.0489,  ...,  0.0250,  0.0083,  0.0164],
#         ...,
#         [-0.0082, -0.0023,  0.0401,  ...,  0.0066, -0.0026,  0.0179],
#         [-0.0113,  0.0155, -0.0036,  ..., -0.0190, -0.0118,  0.0337],
#         [-0.0217, -0.0064, -0.0083,  ...,  0.0188,  0.0026, -0.0066]],
#        requires_grad=True)
# layers.3.self_attn.k_proj.weight: Parameter containing:
# tensor([[ 0.0200,  0.0270,  0.0025,  ...,  0.0165,  0.0140, -0.0163],
#         [ 0.0083, -0.0180, -0.0020,  ...,  0.0255, -0.0225,  0.0068],
#         [ 0.0136, -0.0124, -0.0242,  ...,  0.0068, -0.0280, -0.0068],
#         ...,
#         [ 0.0005,  0.0395, -0.0182,  ...,  0.0123,  0.0025,  0.0053],
#         [ 0.0071,  0.0128, -0.0016,  ...,  0.0054,  0.0397,  0.0167],
#         [-0.0005, -0.0276, -0.0051,  ...,  0.0129,  0.0113, -0.0372]],
#        requires_grad=True)
# layers.3.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 0.0044, -0.0226, -0.0246,  ..., -0.0276,  0.0131,  0.0040],
#         [ 0.0202,  0.0249,  0.0071,  ..., -0.0210, -0.0466, -0.0027],
#         [-0.0178,  0.0222,  0.0471,  ..., -0.0230, -0.0058,  0.0218],
#         ...,
#         [-0.0448,  0.0129, -0.0271,  ..., -0.0168, -0.0083, -0.0159],
#         [-0.0221,  0.0229, -0.0060,  ...,  0.0141,  0.0110,  0.0150],
#         [-0.0032,  0.0231, -0.0111,  ...,  0.0301,  0.0208,  0.0282]],
#        requires_grad=True)
# layers.3.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 1.5396e-03,  3.3321e-02,  1.1724e-02,  ..., -2.9112e-05,
#           4.9603e-03,  3.6257e-02],
#         [-3.0888e-02, -9.7924e-03, -2.9212e-02,  ...,  2.9845e-03,
#           8.0743e-03, -2.1987e-02],
#         [-5.5385e-03,  2.5803e-03, -3.4490e-02,  ..., -3.1331e-02,
#           1.8889e-02, -3.7880e-03],
#         ...,
#         [-2.8680e-02, -2.6740e-02,  1.3325e-02,  ...,  5.0632e-03,
#           1.4149e-02, -3.6688e-02],
#         [-1.1153e-02, -1.8206e-03,  7.0639e-03,  ...,  3.8212e-02,
#           1.2793e-02, -2.4306e-02],
#         [ 7.9603e-03,  1.9875e-02, -3.8901e-02,  ...,  2.0532e-03,
#           2.5471e-02,  2.5484e-02]], requires_grad=True)
# layers.3.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0040, -0.0109, -0.0005,  ..., -0.0131, -0.0035, -0.0133],
#         [-0.0183,  0.0069,  0.0317,  ...,  0.0297,  0.0023, -0.0012],
#         [-0.0276, -0.0031, -0.0012,  ...,  0.0014, -0.0007,  0.0237],
#         ...,
#         [ 0.0287,  0.0010,  0.0340,  ..., -0.0446, -0.0166, -0.0206],
#         [-0.0088, -0.0029,  0.0011,  ...,  0.0341, -0.0192,  0.0154],
#         [ 0.0196,  0.0010, -0.0170,  ...,  0.0221,  0.0024, -0.0013]],
#        requires_grad=True)
# layers.3.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0006, -0.0183,  0.0086,  ..., -0.0104,  0.0049, -0.0052],
#         [-0.0053, -0.0272,  0.0212,  ..., -0.0115, -0.0014,  0.0168],
#         [ 0.0022,  0.0570, -0.0210,  ..., -0.0090,  0.0262,  0.0117],
#         ...,
#         [ 0.0389, -0.0262, -0.0038,  ..., -0.0189,  0.0241, -0.0262],
#         [-0.0246,  0.0166,  0.0043,  ...,  0.0112, -0.0096, -0.0175],
#         [-0.0050,  0.0003,  0.0047,  ..., -0.0075, -0.0035, -0.0393]],
#        requires_grad=True)
# layers.3.mlp.down_proj.weight: Parameter containing:
# tensor([[-0.0219, -0.0161,  0.0168,  ...,  0.0119,  0.0070, -0.0185],
#         [ 0.0082,  0.0190,  0.0120,  ...,  0.0060, -0.0146,  0.0010],
#         [ 0.0071, -0.0316, -0.0287,  ..., -0.0196,  0.0230,  0.0123],
#         ...,
#         [ 0.0310,  0.0184, -0.0253,  ...,  0.0038,  0.0173,  0.0203],
#         [-0.0004,  0.0025,  0.0106,  ...,  0.0115, -0.0084, -0.0005],
#         [ 0.0194, -0.0027,  0.0193,  ...,  0.0065,  0.0019, -0.0008]],
#        requires_grad=True)
# layers.3.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.3.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.4.self_attn.q_proj.weight: Parameter containing:
# tensor([[ 0.0017, -0.0113, -0.0013,  ...,  0.0191, -0.0101, -0.0324],
#         [-0.0219, -0.0319, -0.0066,  ...,  0.0280, -0.0140, -0.0092],
#         [ 0.0010, -0.0533,  0.0020,  ...,  0.0310, -0.0138,  0.0216],
#         ...,
#         [-0.0283,  0.0160,  0.0482,  ..., -0.0121, -0.0279, -0.0186],
#         [-0.0140, -0.0119, -0.0207,  ...,  0.0386, -0.0033, -0.0046],
#         [-0.0043,  0.0024, -0.0226,  ...,  0.0006, -0.0104,  0.0202]],
#        requires_grad=True)
# layers.4.self_attn.k_proj.weight: Parameter containing:
# tensor([[-0.0385, -0.0142, -0.0173,  ...,  0.0043,  0.0240,  0.0043],
#         [-0.0092, -0.0043, -0.0102,  ..., -0.0205, -0.0057,  0.0540],
#         [-0.0207,  0.0400,  0.0115,  ..., -0.0060, -0.0172,  0.0163],
#         ...,
#         [ 0.0083, -0.0048,  0.0145,  ...,  0.0131,  0.0101,  0.0108],
#         [-0.0139, -0.0379, -0.0005,  ..., -0.0401,  0.0083, -0.0120],
#         [ 0.0137, -0.0186, -0.0009,  ...,  0.0346,  0.0182,  0.0097]],
#        requires_grad=True)
# layers.4.self_attn.v_proj.weight: Parameter containing:
# tensor([[-0.0055, -0.0040,  0.0058,  ...,  0.0265, -0.0470, -0.0011],
#         [-0.0163,  0.0431, -0.0139,  ...,  0.0062,  0.0215, -0.0044],
#         [-0.0022, -0.0294, -0.0209,  ...,  0.0177, -0.0088, -0.0275],
#         ...,
#         [ 0.0204,  0.0233, -0.0029,  ..., -0.0209, -0.0084, -0.0222],
#         [ 0.0111, -0.0085,  0.0466,  ..., -0.0058, -0.0018,  0.0076],
#         [-0.0146, -0.0024, -0.0354,  ...,  0.0384, -0.0267,  0.0022]],
#        requires_grad=True)
# layers.4.self_attn.o_proj.weight: Parameter containing:
# tensor([[-0.0095, -0.0127,  0.0110,  ...,  0.0119, -0.0034, -0.0144],
#         [-0.0091, -0.0174, -0.0184,  ...,  0.0318,  0.0093, -0.0203],
#         [ 0.0167, -0.0125,  0.0075,  ...,  0.0081, -0.0143, -0.0060],
#         ...,
#         [ 0.0293,  0.0369,  0.0085,  ...,  0.0019, -0.0088,  0.0023],
#         [ 0.0060, -0.0065, -0.0281,  ..., -0.0296, -0.0029,  0.0297],
#         [-0.0172,  0.0250, -0.0018,  ..., -0.0068, -0.0332,  0.0115]],
#        requires_grad=True)
# layers.4.mlp.gate_proj.weight: Parameter containing:
# tensor([[-7.7389e-03,  2.0872e-02, -2.2771e-02,  ..., -9.4048e-03,
#          -1.7117e-02, -1.2026e-02],
#         [ 3.5940e-02, -2.1756e-02, -3.9031e-02,  ..., -4.5098e-03,
#           1.3627e-05,  2.2408e-03],
#         [-1.0929e-02, -1.3773e-02, -6.2607e-03,  ..., -5.7914e-03,
#          -3.3865e-02, -1.0652e-02],
#         ...,
#         [-4.2717e-02,  1.7978e-02,  2.9061e-02,  ...,  1.8280e-02,
#          -4.9508e-02,  3.1803e-03],
#         [ 1.2187e-02,  1.4052e-02, -5.3910e-03,  ...,  1.3542e-02,
#           2.7950e-03, -2.5248e-03],
#         [ 1.4108e-02,  1.3403e-02, -5.3185e-02,  ..., -1.9463e-02,
#          -3.3957e-02, -2.0330e-02]], requires_grad=True)
# layers.4.mlp.up_proj.weight: Parameter containing:
# tensor([[ 0.0153, -0.0338, -0.0010,  ...,  0.0114,  0.0027,  0.0089],
#         [-0.0112, -0.0237,  0.0015,  ..., -0.0129,  0.0044, -0.0069],
#         [-0.0387,  0.0282,  0.0313,  ..., -0.0333,  0.0171, -0.0033],
#         ...,
#         [-0.0072,  0.0572,  0.0076,  ...,  0.0209,  0.0059,  0.0151],
#         [ 0.0028, -0.0536, -0.0207,  ...,  0.0187, -0.0066, -0.0357],
#         [ 0.0297, -0.0079,  0.0192,  ...,  0.0104, -0.0211, -0.0060]],
#        requires_grad=True)
# layers.4.mlp.down_proj.weight: Parameter containing:
# tensor([[ 0.0041, -0.0069, -0.0060,  ...,  0.0348,  0.0388, -0.0430],
#         [-0.0140, -0.0094,  0.0198,  ..., -0.0277, -0.0220, -0.0088],
#         [ 0.0483, -0.0215, -0.0097,  ..., -0.0085,  0.0315,  0.0034],
#         ...,
#         [-0.0128, -0.0096, -0.0132,  ...,  0.0025,  0.0173, -0.0182],
#         [ 0.0020, -0.0431,  0.0029,  ...,  0.0040, -0.0107, -0.0274],
#         [ 0.0093, -0.0103, -0.0155,  ..., -0.0018, -0.0193,  0.0106]],
#        requires_grad=True)
# layers.4.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.4.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.5.self_attn.q_proj.weight: Parameter containing:
# tensor([[ 0.0082, -0.0144,  0.0249,  ...,  0.0268, -0.0020, -0.0256],
#         [ 0.0242,  0.0160,  0.0192,  ..., -0.0200,  0.0162,  0.0167],
#         [-0.0221, -0.0035, -0.0051,  ..., -0.0015, -0.0099,  0.0112],
#         ...,
#         [-0.0344, -0.0125, -0.0305,  ...,  0.0052, -0.0086,  0.0090],
#         [ 0.0224, -0.0472, -0.0040,  ...,  0.0197,  0.0135, -0.0120],
#         [ 0.0275,  0.0240, -0.0065,  ...,  0.0039,  0.0017,  0.0263]],
#        requires_grad=True)
# layers.5.self_attn.k_proj.weight: Parameter containing:
# tensor([[ 0.0203, -0.0025,  0.0335,  ...,  0.0109,  0.0103,  0.0064],
#         [ 0.0226,  0.0036, -0.0082,  ...,  0.0081, -0.0041,  0.0100],
#         [-0.0016, -0.0260,  0.0122,  ...,  0.0501, -0.0082, -0.0026],
#         ...,
#         [-0.0463,  0.0122, -0.0212,  ..., -0.0138, -0.0046, -0.0060],
#         [-0.0213, -0.0098,  0.0246,  ..., -0.0190, -0.0301, -0.0230],
#         [-0.0337, -0.0012, -0.0205,  ...,  0.0050, -0.0145,  0.0281]],
#        requires_grad=True)
# layers.5.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 0.0054,  0.0151,  0.0096,  ..., -0.0080,  0.0183,  0.0244],
#         [-0.0203,  0.0040, -0.0425,  ...,  0.0537,  0.0005,  0.0194],
#         [-0.0006,  0.0010,  0.0275,  ..., -0.0182, -0.0277,  0.0497],
#         ...,
#         [-0.0235,  0.0024, -0.0237,  ..., -0.0092,  0.0272,  0.0486],
#         [ 0.0015,  0.0263, -0.0269,  ..., -0.0074, -0.0018,  0.0108],
#         [-0.0238,  0.0125,  0.0149,  ..., -0.0069, -0.0243, -0.0052]],
#        requires_grad=True)
# layers.5.self_attn.o_proj.weight: Parameter containing:
# tensor([[-0.0091,  0.0040,  0.0163,  ...,  0.0150,  0.0094, -0.0281],
#         [-0.0035, -0.0214,  0.0025,  ...,  0.0021, -0.0144,  0.0024],
#         [-0.0029, -0.0059,  0.0056,  ...,  0.0115,  0.0409, -0.0036],
#         ...,
#         [-0.0104, -0.0062, -0.0124,  ..., -0.0084, -0.0262, -0.0041],
#         [ 0.0027, -0.0128, -0.0050,  ...,  0.0054, -0.0171,  0.0224],
#         [-0.0049,  0.0050, -0.0028,  ...,  0.0134, -0.0036,  0.0020]],
#        requires_grad=True)
# layers.5.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0243,  0.0052,  0.0053,  ..., -0.0172,  0.0237,  0.0601],
#         [-0.0170, -0.0005,  0.0193,  ..., -0.0295,  0.0296,  0.0442],
#         [-0.0075, -0.0168,  0.0586,  ..., -0.0192, -0.0418, -0.0151],
#         ...,
#         [-0.0153, -0.0142, -0.0282,  ...,  0.0009, -0.0037,  0.0073],
#         [ 0.0288,  0.0256, -0.0030,  ..., -0.0335, -0.0093,  0.0052],
#         [ 0.0283, -0.0005, -0.0109,  ...,  0.0243,  0.0242,  0.0018]],
#        requires_grad=True)
# layers.5.mlp.up_proj.weight: Parameter containing:
# tensor([[ 0.0049, -0.0334, -0.0359,  ..., -0.0302,  0.0188,  0.0068],
#         [-0.0111, -0.0046, -0.0047,  ...,  0.0142, -0.0001, -0.0301],
#         [-0.0025, -0.0247,  0.0230,  ...,  0.0074,  0.0250,  0.0200],
#         ...,
#         [ 0.0152, -0.0050, -0.0194,  ...,  0.0419, -0.0160,  0.0131],
#         [ 0.0183, -0.0233, -0.0138,  ..., -0.0458,  0.0223,  0.0051],
#         [ 0.0148,  0.0061, -0.0177,  ..., -0.0066, -0.0039, -0.0240]],
#        requires_grad=True)
# layers.5.mlp.down_proj.weight: Parameter containing:
# tensor([[-0.0083,  0.0011,  0.0077,  ..., -0.0076,  0.0240,  0.0213],
#         [ 0.0522, -0.0214,  0.0186,  ..., -0.0447,  0.0059, -0.0438],
#         [-0.0278, -0.0120,  0.0531,  ...,  0.0088,  0.0124, -0.0129],
#         ...,
#         [ 0.0033,  0.0214, -0.0006,  ...,  0.0043,  0.0284, -0.0315],
#         [ 0.0139, -0.0251, -0.0050,  ...,  0.0058, -0.0010, -0.0344],
#         [-0.0049,  0.0213,  0.0059,  ...,  0.0170, -0.0028, -0.0174]],
#        requires_grad=True)
# layers.5.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.5.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.6.self_attn.q_proj.weight: Parameter containing:
# tensor([[-0.0024, -0.0197,  0.0153,  ...,  0.0197, -0.0144,  0.0216],
#         [ 0.0131,  0.0365,  0.0314,  ...,  0.0346,  0.0175, -0.0016],
#         [-0.0006, -0.0420,  0.0199,  ...,  0.0307,  0.0039,  0.0268],
#         ...,
#         [ 0.0121, -0.0061,  0.0243,  ..., -0.0251,  0.0143, -0.0098],
#         [-0.0318, -0.0062, -0.0049,  ..., -0.0216,  0.0032, -0.0131],
#         [ 0.0056, -0.0021,  0.0062,  ..., -0.0122, -0.0082, -0.0218]],
#        requires_grad=True)
# layers.6.self_attn.k_proj.weight: Parameter containing:
# tensor([[ 1.5904e-02, -2.1088e-02,  2.2980e-02,  ...,  2.9647e-02,
#           5.9921e-04, -4.1012e-03],
#         [-7.8369e-03,  9.0468e-03,  2.3544e-02,  ..., -8.3122e-03,
#           7.9031e-04,  9.0531e-03],
#         [-4.3933e-02, -4.7410e-03,  3.2307e-05,  ..., -2.4740e-02,
#          -1.5532e-02,  2.8991e-02],
#         ...,
#         [ 7.2368e-03,  1.9029e-02, -5.7677e-03,  ...,  1.4342e-04,
#          -8.5175e-03, -6.1294e-03],
#         [-7.0300e-04, -1.6197e-02, -4.2686e-03,  ...,  6.2567e-04,
#          -5.3978e-03,  8.9092e-03],
#         [ 1.9464e-02,  3.2115e-02, -1.4049e-02,  ..., -8.2848e-03,
#          -3.2064e-02, -2.0586e-02]], requires_grad=True)
# layers.6.self_attn.v_proj.weight: Parameter containing:
# tensor([[-1.4638e-02,  2.4604e-02, -1.1230e-02,  ...,  2.3999e-02,
#           5.3261e-03,  1.6351e-02],
#         [-3.4774e-02, -6.4840e-03, -8.4758e-03,  ...,  2.6813e-02,
#           2.6771e-02, -8.9464e-03],
#         [-4.6170e-02, -1.5465e-02,  2.0792e-02,  ..., -5.7830e-03,
#          -3.5575e-03,  1.1261e-02],
#         ...,
#         [-1.9675e-02, -3.6047e-02,  1.8454e-02,  ...,  7.9780e-03,
#          -2.1064e-02, -1.7554e-02],
#         [ 1.8819e-02,  1.6351e-02, -3.1486e-02,  ..., -5.0167e-02,
#          -1.3589e-02, -3.2442e-02],
#         [ 2.5005e-02, -3.8263e-03,  9.5295e-03,  ..., -1.3176e-03,
#           9.1733e-05, -3.6446e-03]], requires_grad=True)
# layers.6.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 0.0047,  0.0111, -0.0271,  ..., -0.0129, -0.0368, -0.0098],
#         [-0.0278,  0.0070,  0.0156,  ...,  0.0227, -0.0103,  0.0142],
#         [ 0.0047,  0.0177,  0.0076,  ..., -0.0040,  0.0171,  0.0079],
#         ...,
#         [ 0.0195,  0.0354, -0.0081,  ...,  0.0237, -0.0182,  0.0154],
#         [-0.0097, -0.0278,  0.0280,  ..., -0.0143,  0.0156, -0.0068],
#         [ 0.0073, -0.0114, -0.0108,  ..., -0.0080,  0.0098, -0.0231]],
#        requires_grad=True)
# layers.6.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0085, -0.0236, -0.0069,  ...,  0.0171, -0.0128,  0.0343],
#         [ 0.0346,  0.0077,  0.0009,  ..., -0.0270, -0.0121, -0.0105],
#         [-0.0109,  0.0091,  0.0222,  ..., -0.0340, -0.0168, -0.0264],
#         ...,
#         [ 0.0351, -0.0319, -0.0312,  ..., -0.0085,  0.0326, -0.0216],
#         [-0.0173, -0.0098,  0.0080,  ...,  0.0296,  0.0011,  0.0221],
#         [ 0.0257,  0.0141, -0.0109,  ...,  0.0274, -0.0008, -0.0134]],
#        requires_grad=True)
# layers.6.mlp.up_proj.weight: Parameter containing:
# tensor([[ 0.0042,  0.0500, -0.0037,  ...,  0.0268,  0.0144,  0.0200],
#         [-0.0018,  0.0038,  0.0079,  ...,  0.0055,  0.0134, -0.0102],
#         [ 0.0285, -0.0075,  0.0006,  ..., -0.0008,  0.0067,  0.0218],
#         ...,
#         [ 0.0298, -0.0091,  0.0024,  ...,  0.0004, -0.0248,  0.0049],
#         [-0.0313,  0.0211, -0.0051,  ..., -0.0033, -0.0098,  0.0242],
#         [ 0.0124, -0.0270,  0.0330,  ...,  0.0195, -0.0070,  0.0223]],
#        requires_grad=True)
# layers.6.mlp.down_proj.weight: Parameter containing:
# tensor([[ 0.0283,  0.0178, -0.0055,  ..., -0.0194,  0.0053, -0.0004],
#         [ 0.0216, -0.0205, -0.0137,  ...,  0.0146, -0.0113,  0.0123],
#         [ 0.0177, -0.0053,  0.0003,  ...,  0.0085, -0.0131,  0.0078],
#         ...,
#         [ 0.0111,  0.0020,  0.0165,  ...,  0.0208, -0.0123, -0.0531],
#         [-0.0269, -0.0183, -0.0207,  ..., -0.0193, -0.0110,  0.0061],
#         [-0.0014, -0.0089, -0.0083,  ..., -0.0066, -0.0271, -0.0173]],
#        requires_grad=True)
# layers.6.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.6.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.7.self_attn.q_proj.weight: Parameter containing:
# tensor([[-0.0254, -0.0092,  0.0227,  ..., -0.0229, -0.0104,  0.0051],
#         [-0.0075,  0.0144,  0.0223,  ..., -0.0104, -0.0213, -0.0225],
#         [ 0.0101,  0.0240, -0.0133,  ..., -0.0276, -0.0128, -0.0133],
#         ...,
#         [ 0.0100, -0.0293, -0.0012,  ..., -0.0142, -0.0061, -0.0318],
#         [-0.0193, -0.0007,  0.0163,  ...,  0.0058, -0.0194,  0.0101],
#         [-0.0153, -0.0009, -0.0064,  ...,  0.0173,  0.0211,  0.0112]],
#        requires_grad=True)
# layers.7.self_attn.k_proj.weight: Parameter containing:
# tensor([[ 0.0138, -0.0317,  0.0090,  ...,  0.0318,  0.0075, -0.0109],
#         [ 0.0102,  0.0136, -0.0109,  ...,  0.0019, -0.0121, -0.0131],
#         [-0.0129,  0.0324, -0.0338,  ...,  0.0036, -0.0151, -0.0110],
#         ...,
#         [-0.0005,  0.0009, -0.0087,  ..., -0.0205, -0.0137, -0.0165],
#         [ 0.0349,  0.0253,  0.0506,  ..., -0.0147, -0.0014,  0.0064],
#         [ 0.0011,  0.0153,  0.0132,  ...,  0.0244, -0.0033,  0.0390]],
#        requires_grad=True)
# layers.7.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 2.7002e-02,  6.3296e-03,  2.2710e-02,  ..., -2.6040e-03,
#           2.7219e-02,  5.1445e-03],
#         [ 2.3367e-02,  3.8173e-02, -2.8730e-03,  ..., -3.1415e-02,
#           5.3953e-03, -4.9836e-03],
#         [-5.0110e-06, -3.5627e-02,  4.7403e-02,  ...,  6.6021e-03,
#           7.9742e-03,  2.4832e-02],
#         ...,
#         [-3.0722e-02, -2.8340e-02, -1.6085e-02,  ...,  2.6768e-02,
#          -1.6470e-03, -3.1317e-02],
#         [-1.3563e-02,  3.4210e-02, -1.5650e-02,  ..., -1.5650e-02,
#          -1.6402e-02, -1.5514e-02],
#         [ 1.4464e-02, -2.0494e-02,  1.5286e-02,  ..., -2.6978e-02,
#          -2.1390e-02,  2.5322e-02]], requires_grad=True)
# layers.7.self_attn.o_proj.weight: Parameter containing:
# tensor([[-0.0125, -0.0219,  0.0100,  ...,  0.0141, -0.0049, -0.0065],
#         [ 0.0123,  0.0124,  0.0009,  ..., -0.0332, -0.0461,  0.0141],
#         [ 0.0076, -0.0128,  0.0432,  ...,  0.0116,  0.0455, -0.0004],
#         ...,
#         [ 0.0045, -0.0054, -0.0232,  ...,  0.0020, -0.0287, -0.0225],
#         [ 0.0252,  0.0014, -0.0148,  ...,  0.0137, -0.0007, -0.0310],
#         [-0.0034,  0.0052,  0.0286,  ..., -0.0499,  0.0046, -0.0076]],
#        requires_grad=True)
# layers.7.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0163,  0.0134,  0.0097,  ...,  0.0097, -0.0121, -0.0001],
#         [-0.0239,  0.0180, -0.0201,  ...,  0.0309, -0.0165, -0.0123],
#         [-0.0146,  0.0240, -0.0100,  ...,  0.0163,  0.0275,  0.0111],
#         ...,
#         [-0.0272, -0.0047, -0.0214,  ..., -0.0130, -0.0353, -0.0276],
#         [ 0.0075, -0.0002, -0.0048,  ...,  0.0317,  0.0399,  0.0134],
#         [ 0.0212, -0.0170, -0.0147,  ..., -0.0090, -0.0199, -0.0374]],
#        requires_grad=True)
# layers.7.mlp.up_proj.weight: Parameter containing:
# tensor([[ 0.0074, -0.0270, -0.0112,  ...,  0.0341,  0.0152,  0.0121],
#         [-0.0044, -0.0157, -0.0286,  ...,  0.0175, -0.0292,  0.0286],
#         [-0.0035, -0.0501, -0.0254,  ..., -0.0136, -0.0510, -0.0218],
#         ...,
#         [-0.0116, -0.0069, -0.0255,  ..., -0.0297, -0.0016,  0.0095],
#         [-0.0146,  0.0158,  0.0293,  ...,  0.0202,  0.0166, -0.0184],
#         [ 0.0293,  0.0486, -0.0148,  ..., -0.0041, -0.0250, -0.0020]],
#        requires_grad=True)
# layers.7.mlp.down_proj.weight: Parameter containing:
# tensor([[-0.0057,  0.0140,  0.0142,  ...,  0.0195, -0.0165, -0.0272],
#         [-0.0049,  0.0440,  0.0349,  ...,  0.0211, -0.0111,  0.0017],
#         [-0.0169, -0.0027, -0.0090,  ..., -0.0018, -0.0111, -0.0011],
#         ...,
#         [ 0.0148, -0.0193, -0.0098,  ...,  0.0095,  0.0025, -0.0081],
#         [ 0.0255,  0.0237, -0.0247,  ..., -0.0017, -0.0215, -0.0062],
#         [-0.0105, -0.0017, -0.0145,  ..., -0.0145, -0.0169,  0.0400]],
#        requires_grad=True)
# layers.7.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.7.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.8.self_attn.q_proj.weight: Parameter containing:
# tensor([[ 0.0261, -0.0240,  0.0056,  ...,  0.0265, -0.0077, -0.0480],
#         [-0.0054,  0.0169,  0.0036,  ...,  0.0149,  0.0005, -0.0013],
#         [ 0.0065, -0.0151,  0.0498,  ...,  0.0010, -0.0171, -0.0018],
#         ...,
#         [ 0.0303, -0.0012,  0.0387,  ...,  0.0249, -0.0004,  0.0211],
#         [ 0.0139, -0.0101,  0.0086,  ..., -0.0009, -0.0237,  0.0379],
#         [ 0.0031, -0.0133,  0.0189,  ..., -0.0304, -0.0081, -0.0074]],
#        requires_grad=True)
# layers.8.self_attn.k_proj.weight: Parameter containing:
# tensor([[-0.0021, -0.0242, -0.0058,  ...,  0.0190, -0.0158, -0.0057],
#         [-0.0039, -0.0068, -0.0073,  ..., -0.0313,  0.0242, -0.0353],
#         [ 0.0072, -0.0044,  0.0042,  ...,  0.0019,  0.0156,  0.0139],
#         ...,
#         [ 0.0015,  0.0038,  0.0232,  ...,  0.0117, -0.0130, -0.0147],
#         [ 0.0230,  0.0162, -0.0080,  ...,  0.0025, -0.0285,  0.0201],
#         [ 0.0260,  0.0116,  0.0045,  ..., -0.0049, -0.0191, -0.0033]],
#        requires_grad=True)
# layers.8.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 1.2789e-02,  1.4914e-02, -7.3579e-03,  ...,  2.7113e-02,
#          -8.3155e-03,  8.1435e-03],
#         [ 3.5902e-02,  1.9907e-02,  7.5885e-03,  ...,  1.0991e-02,
#          -1.5331e-02,  1.1545e-02],
#         [ 1.9339e-03, -2.5084e-02,  5.4434e-03,  ..., -2.7933e-05,
#           1.9623e-02, -1.8339e-02],
#         ...,
#         [-1.2969e-02,  3.2256e-02, -6.1627e-03,  ..., -1.3563e-03,
#          -1.0409e-02, -1.5039e-02],
#         [ 1.4448e-03,  4.8490e-03, -3.2733e-02,  ..., -1.5192e-02,
#           2.5823e-02, -5.6712e-03],
#         [ 4.2111e-02, -1.4255e-03, -1.4792e-02,  ..., -8.4995e-03,
#          -1.0699e-02, -2.9346e-02]], requires_grad=True)
# layers.8.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 0.0064, -0.0086, -0.0174,  ..., -0.0235,  0.0136, -0.0109],
#         [ 0.0572, -0.0073, -0.0041,  ...,  0.0073,  0.0366,  0.0127],
#         [-0.0166,  0.0223, -0.0229,  ...,  0.0194, -0.0280,  0.0087],
#         ...,
#         [ 0.0130,  0.0249,  0.0101,  ..., -0.0355, -0.0212, -0.0130],
#         [-0.0130,  0.0060, -0.0044,  ..., -0.0271,  0.0116, -0.0004],
#         [ 0.0081,  0.0192, -0.0076,  ..., -0.0307, -0.0087,  0.0200]],
#        requires_grad=True)
# layers.8.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0017,  0.0258, -0.0275,  ..., -0.0213,  0.0204,  0.0041],
#         [-0.0477, -0.0279,  0.0325,  ...,  0.0046, -0.0298,  0.0071],
#         [ 0.0085,  0.0032, -0.0037,  ...,  0.0100, -0.0014,  0.0214],
#         ...,
#         [ 0.0043,  0.0105, -0.0111,  ..., -0.0583,  0.0291,  0.0257],
#         [-0.0095,  0.0033, -0.0062,  ...,  0.0204, -0.0176, -0.0113],
#         [ 0.0038, -0.0260, -0.0048,  ...,  0.0372, -0.0260, -0.0057]],
#        requires_grad=True)
# layers.8.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0164,  0.0003,  0.0267,  ..., -0.0311, -0.0038,  0.0301],
#         [ 0.0042,  0.0470, -0.0138,  ..., -0.0439, -0.0293,  0.0109],
#         [ 0.0308,  0.0109, -0.0196,  ...,  0.0147, -0.0373,  0.0189],
#         ...,
#         [ 0.0209,  0.0039, -0.0305,  ...,  0.0184, -0.0051, -0.0094],
#         [-0.0196,  0.0001, -0.0287,  ...,  0.0114, -0.0080, -0.0136],
#         [-0.0062,  0.0079, -0.0101,  ..., -0.0104,  0.0125, -0.0161]],
#        requires_grad=True)
# layers.8.mlp.down_proj.weight: Parameter containing:
# tensor([[ 0.0110, -0.0353,  0.0019,  ...,  0.0105, -0.0144, -0.0198],
#         [-0.0026, -0.0272,  0.0209,  ..., -0.0104,  0.0037,  0.0121],
#         [-0.0185,  0.0221,  0.0031,  ...,  0.0014, -0.0237,  0.0474],
#         ...,
#         [-0.0527, -0.0016, -0.0375,  ...,  0.0353,  0.0032,  0.0090],
#         [-0.0158, -0.0059,  0.0238,  ..., -0.0163,  0.0143,  0.0300],
#         [ 0.0030,  0.0327,  0.0057,  ..., -0.0015, -0.0174,  0.0108]],
#        requires_grad=True)
# layers.8.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.8.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.9.self_attn.q_proj.weight: Parameter containing:
# tensor([[ 0.0192,  0.0194,  0.0225,  ...,  0.0054,  0.0164, -0.0221],
#         [ 0.0239, -0.0025, -0.0150,  ..., -0.0064, -0.0337,  0.0257],
#         [-0.0064,  0.0456,  0.0200,  ...,  0.0181, -0.0338, -0.0182],
#         ...,
#         [-0.0053,  0.0200,  0.0043,  ..., -0.0253,  0.0005,  0.0092],
#         [-0.0040, -0.0366, -0.0074,  ..., -0.0061,  0.0068,  0.0483],
#         [-0.0142,  0.0114, -0.0104,  ..., -0.0106,  0.0107, -0.0030]],
#        requires_grad=True)
# layers.9.self_attn.k_proj.weight: Parameter containing:
# tensor([[-2.2561e-02, -2.0884e-03, -2.2609e-04,  ...,  1.2697e-02,
#           2.8634e-02, -2.8651e-02],
#         [ 1.0176e-02, -8.3694e-03,  2.8877e-02,  ...,  1.0896e-02,
#          -2.5993e-04,  3.3952e-02],
#         [ 7.3507e-05, -4.4153e-02,  3.4357e-02,  ..., -2.0718e-02,
#          -1.7337e-02,  1.2245e-02],
#         ...,
#         [-2.2552e-02, -6.9792e-03, -8.7826e-03,  ..., -3.2663e-02,
#           3.0952e-03,  3.6955e-02],
#         [ 1.5662e-02, -7.0291e-03, -2.3562e-03,  ..., -2.5307e-03,
#           7.4961e-03,  3.1047e-03],
#         [-5.8985e-03,  1.7501e-03, -2.6202e-02,  ...,  6.6327e-05,
#          -1.7248e-02,  1.8218e-02]], requires_grad=True)
# layers.9.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 0.0296, -0.0034, -0.0267,  ..., -0.0111, -0.0175, -0.0147],
#         [-0.0062,  0.0019,  0.0009,  ...,  0.0227,  0.0266, -0.0060],
#         [-0.0361,  0.0188, -0.0480,  ...,  0.0120, -0.0027,  0.0063],
#         ...,
#         [-0.0014, -0.0327, -0.0141,  ...,  0.0101,  0.0012, -0.0260],
#         [-0.0008, -0.0264,  0.0167,  ...,  0.0509, -0.0093, -0.0206],
#         [ 0.0143, -0.0047, -0.0256,  ..., -0.0014,  0.0027, -0.0065]],
#        requires_grad=True)
# layers.9.self_attn.o_proj.weight: Parameter containing:
# tensor([[-0.0442, -0.0337,  0.0197,  ..., -0.0229,  0.0111, -0.0123],
#         [ 0.0233,  0.0232,  0.0347,  ...,  0.0224,  0.0192,  0.0238],
#         [-0.0616, -0.0045,  0.0121,  ...,  0.0110,  0.0038,  0.0463],
#         ...,
#         [ 0.0020,  0.0149, -0.0248,  ...,  0.0156,  0.0383, -0.0213],
#         [ 0.0303,  0.0026, -0.0129,  ...,  0.0052,  0.0002, -0.0128],
#         [-0.0075, -0.0073,  0.0364,  ...,  0.0223,  0.0273,  0.0050]],
#        requires_grad=True)
# layers.9.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0287,  0.0013, -0.0113,  ...,  0.0245,  0.0214,  0.0073],
#         [-0.0100, -0.0192,  0.0060,  ...,  0.0020,  0.0028,  0.0102],
#         [ 0.0049, -0.0043, -0.0189,  ..., -0.0371,  0.0314, -0.0055],
#         ...,
#         [ 0.0179, -0.0239, -0.0166,  ..., -0.0581, -0.0297,  0.0090],
#         [-0.0018,  0.0159,  0.0119,  ...,  0.0028, -0.0005, -0.0218],
#         [ 0.0015, -0.0380,  0.0478,  ...,  0.0032, -0.0237,  0.0382]],
#        requires_grad=True)
# layers.9.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0059,  0.0074, -0.0111,  ..., -0.0336, -0.0271,  0.0025],
#         [ 0.0082, -0.0085, -0.0065,  ..., -0.0192, -0.0111,  0.0026],
#         [ 0.0008, -0.0003,  0.0059,  ...,  0.0245, -0.0141,  0.0090],
#         ...,
#         [-0.0003,  0.0123,  0.0082,  ...,  0.0014, -0.0112,  0.0274],
#         [-0.0030, -0.0374, -0.0015,  ..., -0.0043,  0.0103, -0.0359],
#         [ 0.0152,  0.0081, -0.0104,  ..., -0.0204, -0.0254,  0.0156]],
#        requires_grad=True)
# layers.9.mlp.down_proj.weight: Parameter containing:
# tensor([[ 0.0327,  0.0246,  0.0037,  ...,  0.0189,  0.0174,  0.0036],
#         [ 0.0123,  0.0171, -0.0396,  ...,  0.0376, -0.0066,  0.0196],
#         [-0.0095, -0.0250,  0.0036,  ...,  0.0095, -0.0411, -0.0033],
#         ...,
#         [-0.0179, -0.0064, -0.0226,  ..., -0.0278,  0.0085, -0.0159],
#         [-0.0145,  0.0095,  0.0022,  ...,  0.0132,  0.0147, -0.0294],
#         [ 0.0371,  0.0105,  0.0014,  ..., -0.0314,  0.0065, -0.0043]],
#        requires_grad=True)
# layers.9.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.9.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.10.self_attn.q_proj.weight: Parameter containing:
# tensor([[-0.0240, -0.0053, -0.0051,  ...,  0.0130,  0.0099, -0.0061],
#         [ 0.0202,  0.0099, -0.0023,  ..., -0.0090,  0.0230,  0.0137],
#         [ 0.0101,  0.0031,  0.0192,  ..., -0.0359, -0.0137,  0.0320],
#         ...,
#         [ 0.0280, -0.0274,  0.0041,  ..., -0.0372, -0.0112,  0.0383],
#         [ 0.0331,  0.0127,  0.0132,  ...,  0.0088,  0.0110,  0.0293],
#         [ 0.0025, -0.0187,  0.0012,  ..., -0.0100,  0.0147,  0.0087]],
#        requires_grad=True)
# layers.10.self_attn.k_proj.weight: Parameter containing:
# tensor([[-0.0038, -0.0033, -0.0027,  ..., -0.0224,  0.0236, -0.0255],
#         [-0.0142,  0.0092,  0.0304,  ..., -0.0273, -0.0125,  0.0320],
#         [ 0.0146,  0.0276, -0.0303,  ..., -0.0142, -0.0040, -0.0314],
#         ...,
#         [ 0.0255, -0.0047,  0.0312,  ..., -0.0093,  0.0198,  0.0151],
#         [ 0.0207, -0.0104, -0.0113,  ..., -0.0033,  0.0197,  0.0172],
#         [-0.0070,  0.0027, -0.0106,  ...,  0.0038,  0.0420,  0.0001]],
#        requires_grad=True)
# layers.10.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 0.0259,  0.0257,  0.0249,  ...,  0.0329,  0.0100,  0.0068],
#         [-0.0119,  0.0245,  0.0066,  ...,  0.0348, -0.0316, -0.0100],
#         [ 0.0090, -0.0329,  0.0113,  ...,  0.0448,  0.0234, -0.0061],
#         ...,
#         [-0.0173, -0.0254,  0.0082,  ...,  0.0340, -0.0010, -0.0160],
#         [-0.0355,  0.0052,  0.0125,  ..., -0.0197,  0.0016,  0.0007],
#         [-0.0105,  0.0104, -0.0191,  ...,  0.0102, -0.0157,  0.0117]],
#        requires_grad=True)
# layers.10.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 0.0196,  0.0096,  0.0274,  ...,  0.0114,  0.0087,  0.0197],
#         [-0.0242,  0.0157, -0.0412,  ..., -0.0336,  0.0014, -0.0217],
#         [-0.0101,  0.0066,  0.0293,  ...,  0.0202,  0.0228,  0.0122],
#         ...,
#         [-0.0199,  0.0340,  0.0337,  ..., -0.0227,  0.0074,  0.0429],
#         [ 0.0322,  0.0081,  0.0129,  ...,  0.0313,  0.0051, -0.0354],
#         [ 0.0076,  0.0059,  0.0357,  ...,  0.0310, -0.0135, -0.0173]],
#        requires_grad=True)
# layers.10.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0127,  0.0059,  0.0284,  ...,  0.0046, -0.0091,  0.0038],
#         [ 0.0100,  0.0483, -0.0495,  ...,  0.0080,  0.0043,  0.0061],
#         [-0.0366,  0.0116,  0.0067,  ..., -0.0367,  0.0257,  0.0252],
#         ...,
#         [ 0.0011,  0.0118, -0.0194,  ...,  0.0145,  0.0279, -0.0149],
#         [ 0.0140,  0.0299,  0.0205,  ..., -0.0072,  0.0524, -0.0217],
#         [ 0.0030,  0.0144,  0.0148,  ..., -0.0054, -0.0070, -0.0226]],
#        requires_grad=True)
# layers.10.mlp.up_proj.weight: Parameter containing:
# tensor([[ 0.0096,  0.0262,  0.0021,  ..., -0.0352,  0.0084,  0.0259],
#         [-0.0314,  0.0145,  0.0210,  ...,  0.0194,  0.0257,  0.0266],
#         [-0.0186, -0.0424, -0.0241,  ..., -0.0190, -0.0024,  0.0032],
#         ...,
#         [-0.0088,  0.0046,  0.0046,  ...,  0.0142,  0.0046, -0.0192],
#         [-0.0298, -0.0152, -0.0044,  ...,  0.0282,  0.0049,  0.0096],
#         [-0.0210,  0.0504,  0.0101,  ...,  0.0018, -0.0017, -0.0116]],
#        requires_grad=True)
# layers.10.mlp.down_proj.weight: Parameter containing:
# tensor([[ 0.0175, -0.0073,  0.0495,  ...,  0.0009, -0.0113, -0.0125],
#         [-0.0026,  0.0002, -0.0027,  ...,  0.0026,  0.0164,  0.0059],
#         [ 0.0200,  0.0107, -0.0040,  ..., -0.0240, -0.0052,  0.0028],
#         ...,
#         [-0.0062, -0.0106,  0.0091,  ..., -0.0031,  0.0053, -0.0121],
#         [-0.0029, -0.0007, -0.0339,  ..., -0.0150, -0.0232, -0.0112],
#         [-0.0127, -0.0070, -0.0084,  ...,  0.0076,  0.0203, -0.0260]],
#        requires_grad=True)
# layers.10.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.10.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.11.self_attn.q_proj.weight: Parameter containing:
# tensor([[-0.0207, -0.0171, -0.0067,  ..., -0.0306, -0.0151,  0.0391],
#         [ 0.0126,  0.0067, -0.0170,  ...,  0.0251,  0.0704, -0.0318],
#         [-0.0038,  0.0157,  0.0051,  ..., -0.0299,  0.0282, -0.0451],
#         ...,
#         [ 0.0279, -0.0160,  0.0182,  ..., -0.0248, -0.0205,  0.0580],
#         [-0.0082, -0.0243,  0.0016,  ..., -0.0197, -0.0057,  0.0044],
#         [-0.0240, -0.0146, -0.0052,  ...,  0.0241,  0.0099,  0.0104]],
#        requires_grad=True)
# layers.11.self_attn.k_proj.weight: Parameter containing:
# tensor([[-0.0080,  0.0505,  0.0028,  ..., -0.0154,  0.0303, -0.0067],
#         [ 0.0052,  0.0010, -0.0348,  ..., -0.0180,  0.0139,  0.0052],
#         [ 0.0129,  0.0055, -0.0197,  ...,  0.0212, -0.0326,  0.0423],
#         ...,
#         [ 0.0107,  0.0170,  0.0122,  ...,  0.0112,  0.0059,  0.0151],
#         [ 0.0176, -0.0306, -0.0111,  ..., -0.0171, -0.0097,  0.0071],
#         [ 0.0039, -0.0484,  0.0044,  ..., -0.0234,  0.0258,  0.0304]],
#        requires_grad=True)
# layers.11.self_attn.v_proj.weight: Parameter containing:
# tensor([[-0.0152, -0.0111, -0.0233,  ..., -0.0036, -0.0079,  0.0131],
#         [-0.0141, -0.0028,  0.0031,  ...,  0.0042,  0.0052, -0.0093],
#         [-0.0135,  0.0139, -0.0115,  ...,  0.0048, -0.0203,  0.0271],
#         ...,
#         [ 0.0242,  0.0436,  0.0015,  ..., -0.0285, -0.0185, -0.0072],
#         [-0.0323, -0.0231,  0.0385,  ..., -0.0210, -0.0027,  0.0089],
#         [-0.0055, -0.0072,  0.0024,  ...,  0.0067, -0.0288,  0.0007]],
#        requires_grad=True)
# layers.11.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 0.0009, -0.0480,  0.0039,  ...,  0.0159,  0.0231, -0.0369],
#         [ 0.0022, -0.0099, -0.0006,  ..., -0.0101,  0.0113,  0.0030],
#         [ 0.0237,  0.0129,  0.0128,  ...,  0.0187,  0.0021, -0.0116],
#         ...,
#         [-0.0180,  0.0242,  0.0116,  ...,  0.0177,  0.0381, -0.0223],
#         [ 0.0020,  0.0008, -0.0094,  ..., -0.0191,  0.0100,  0.0192],
#         [ 0.0062, -0.0277,  0.0045,  ...,  0.0071, -0.0050, -0.0017]],
#        requires_grad=True)
# layers.11.mlp.gate_proj.weight: Parameter containing:
# tensor([[-0.0093, -0.0168,  0.0590,  ..., -0.0071, -0.0074,  0.0078],
#         [ 0.0181,  0.0018, -0.0015,  ..., -0.0170, -0.0135,  0.0107],
#         [-0.0016,  0.0383,  0.0058,  ..., -0.0093,  0.0054, -0.0173],
#         ...,
#         [-0.0058,  0.0092,  0.0129,  ..., -0.0107, -0.0216, -0.0127],
#         [-0.0295,  0.0182, -0.0236,  ..., -0.0204, -0.0196,  0.0345],
#         [-0.0388,  0.0169, -0.0432,  ..., -0.0217,  0.0185, -0.0068]],
#        requires_grad=True)
# layers.11.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0037,  0.0132, -0.0092,  ..., -0.0301, -0.0263,  0.0317],
#         [-0.0109, -0.0239, -0.0371,  ...,  0.0158,  0.0205,  0.0061],
#         [ 0.0188, -0.0070,  0.0291,  ...,  0.0108,  0.0002,  0.0094],
#         ...,
#         [ 0.0207, -0.0112, -0.0522,  ..., -0.0108, -0.0341, -0.0123],
#         [-0.0060, -0.0009,  0.0178,  ...,  0.0288, -0.0033, -0.0044],
#         [ 0.0091,  0.0052, -0.0218,  ..., -0.0212,  0.0002, -0.0197]],
#        requires_grad=True)
# layers.11.mlp.down_proj.weight: Parameter containing:
# tensor([[ 0.0139, -0.0062,  0.0156,  ...,  0.0248,  0.0096,  0.0042],
#         [-0.0037, -0.0010, -0.0042,  ..., -0.0211,  0.0078,  0.0099],
#         [-0.0086,  0.0032,  0.0011,  ..., -0.0122, -0.0023, -0.0084],
#         ...,
#         [-0.0038,  0.0037, -0.0058,  ...,  0.0091,  0.0150, -0.0109],
# ...
#         [ 0.0138, -0.0230, -0.0137,  ...,  0.0046,  0.0065,  0.0061],
#         [-0.0159, -0.0036,  0.0223,  ..., -0.0131, -0.0179,  0.0207]],
#        requires_grad=True)
# layers.28.self_attn.v_proj.weight: Parameter containing:
# tensor([[-0.0095, -0.0060,  0.0146,  ..., -0.0076, -0.0073, -0.0011],
#         [ 0.0172,  0.0117, -0.0200,  ...,  0.0024,  0.0358,  0.0011],
#         [-0.0047, -0.0333,  0.0227,  ..., -0.0100, -0.0158, -0.0713],
#         ...,
#         [ 0.0054,  0.0264, -0.0006,  ...,  0.0233,  0.0323,  0.0232],
#         [ 0.0074,  0.0081, -0.0227,  ..., -0.0302, -0.0019,  0.0062],
#         [ 0.0017,  0.0054, -0.0081,  ...,  0.0111,  0.0108,  0.0268]],
#        requires_grad=True)
# layers.28.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 0.0195, -0.0051, -0.0180,  ..., -0.0198, -0.0234,  0.0106],
#         [ 0.0128, -0.0062, -0.0077,  ..., -0.0293, -0.0165, -0.0128],
#         [ 0.0445, -0.0331, -0.0006,  ..., -0.0051,  0.0298, -0.0267],
#         ...,
#         [ 0.0038,  0.0137,  0.0034,  ..., -0.0085, -0.0174,  0.0197],
#         [-0.0151, -0.0293,  0.0089,  ..., -0.0071,  0.0059,  0.0101],
#         [-0.0010,  0.0045, -0.0346,  ..., -0.0181, -0.0257, -0.0097]],
#        requires_grad=True)
# layers.28.mlp.gate_proj.weight: Parameter containing:
# tensor([[-0.0103,  0.0127,  0.0414,  ...,  0.0265, -0.0003, -0.0041],
#         [ 0.0310, -0.0190, -0.0242,  ...,  0.0149,  0.0111,  0.0106],
#         [ 0.0005,  0.0087,  0.0017,  ...,  0.0002, -0.0014,  0.0066],
#         ...,
#         [-0.0259, -0.0047,  0.0391,  ...,  0.0033,  0.0024,  0.0141],
#         [ 0.0086, -0.0102,  0.0354,  ..., -0.0357, -0.0459, -0.0240],
#         [ 0.0304, -0.0174,  0.0124,  ...,  0.0328,  0.0097, -0.0489]],
#        requires_grad=True)
# layers.28.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0310, -0.0449,  0.0067,  ..., -0.0055,  0.0090,  0.0071],
#         [-0.0124, -0.0220,  0.0106,  ...,  0.0043, -0.0136, -0.0274],
#         [ 0.0066, -0.0050,  0.0434,  ..., -0.0010, -0.0002,  0.0009],
#         ...,
#         [ 0.0029, -0.0081,  0.0128,  ...,  0.0317,  0.0025, -0.0078],
#         [-0.0115, -0.0073, -0.0060,  ..., -0.0013, -0.0107,  0.0056],
#         [-0.0163, -0.0248,  0.0005,  ..., -0.0006, -0.0236, -0.0108]],
#        requires_grad=True)
# layers.28.mlp.down_proj.weight: Parameter containing:
# tensor([[-0.0366,  0.0012,  0.0049,  ...,  0.0007, -0.0147, -0.0078],
#         [ 0.0024,  0.0235,  0.0070,  ..., -0.0030,  0.0042, -0.0156],
#         [ 0.0235, -0.0067,  0.0393,  ..., -0.0330,  0.0036,  0.0067],
#         ...,
#         [ 0.0097,  0.0309,  0.0093,  ..., -0.0229, -0.0216, -0.0139],
#         [-0.0156, -0.0034, -0.0067,  ...,  0.0079, -0.0006, -0.0189],
#         [-0.0171, -0.0016, -0.0131,  ..., -0.0138, -0.0042, -0.0156]],
#        requires_grad=True)
# layers.28.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.28.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.29.self_attn.q_proj.weight: Parameter containing:
# tensor([[-0.0013, -0.0277, -0.0022,  ..., -0.0055,  0.0133, -0.0158],
#         [ 0.0153,  0.0209,  0.0302,  ..., -0.0221,  0.0074,  0.0081],
#         [-0.0142, -0.0045,  0.0105,  ..., -0.0193, -0.0065, -0.0004],
#         ...,
#         [-0.0416, -0.0061,  0.0126,  ...,  0.0128,  0.0148,  0.0097],
#         [ 0.0208, -0.0173,  0.0141,  ...,  0.0240, -0.0186, -0.0043],
#         [-0.0106, -0.0052, -0.0196,  ..., -0.0327, -0.0331,  0.0105]],
#        requires_grad=True)
# layers.29.self_attn.k_proj.weight: Parameter containing:
# tensor([[-0.0095, -0.0071,  0.0012,  ..., -0.0232, -0.0088,  0.0227],
#         [-0.0376, -0.0113, -0.0129,  ..., -0.0305,  0.0138, -0.0137],
#         [ 0.0122,  0.0108,  0.0076,  ...,  0.0104,  0.0032, -0.0180],
#         ...,
#         [ 0.0278, -0.0251,  0.0175,  ...,  0.0142, -0.0134,  0.0150],
#         [-0.0021,  0.0051, -0.0402,  ...,  0.0032,  0.0228, -0.0002],
#         [ 0.0186,  0.0160,  0.0043,  ...,  0.0218, -0.0112,  0.0121]],
#        requires_grad=True)
# layers.29.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 0.0152,  0.0145,  0.0084,  ..., -0.0018, -0.0397, -0.0267],
#         [ 0.0192,  0.0169, -0.0233,  ..., -0.0011, -0.0048, -0.0273],
#         [ 0.0186,  0.0124, -0.0138,  ...,  0.0142, -0.0271,  0.0122],
#         ...,
#         [ 0.0001, -0.0219,  0.0043,  ...,  0.0250, -0.0170, -0.0325],
#         [-0.0031, -0.0187, -0.0304,  ...,  0.0445,  0.0176,  0.0244],
#         [-0.0075,  0.0023,  0.0446,  ..., -0.0026,  0.0207, -0.0172]],
#        requires_grad=True)
# layers.29.self_attn.o_proj.weight: Parameter containing:
# tensor([[ 1.9392e-02,  2.1629e-02, -1.9205e-03,  ..., -3.1884e-02,
#          -3.0787e-02, -4.1045e-02],
#         [ 1.9541e-02,  2.4461e-02,  1.2805e-02,  ..., -1.8740e-02,
#          -1.8743e-02,  6.5514e-03],
#         [-2.2929e-02,  2.1341e-03, -2.0136e-02,  ..., -1.6818e-02,
#           3.9685e-03, -1.6527e-02],
#         ...,
#         [-9.7698e-03, -2.4908e-03, -8.2346e-04,  ..., -1.5167e-05,
#           1.9002e-02, -2.5935e-03],
#         [ 4.4752e-02,  3.0039e-02, -1.0161e-02,  ..., -2.6802e-02,
#          -8.0573e-03, -7.9481e-03],
#         [-8.7244e-03,  3.5309e-02, -1.0775e-02,  ...,  1.1775e-02,
#           2.8973e-02, -2.1025e-02]], requires_grad=True)
# layers.29.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0223,  0.0226,  0.0296,  ..., -0.0129, -0.0412,  0.0226],
#         [-0.0362,  0.0180,  0.0033,  ..., -0.0317, -0.0053,  0.0114],
#         [ 0.0048,  0.0077,  0.0100,  ..., -0.0082,  0.0271,  0.0046],
#         ...,
#         [-0.0007,  0.0101,  0.0241,  ...,  0.0179,  0.0078,  0.0022],
#         [ 0.0292,  0.0107,  0.0305,  ...,  0.0009,  0.0218, -0.0121],
#         [ 0.0074, -0.0184, -0.0085,  ...,  0.0306,  0.0188,  0.0208]],
#        requires_grad=True)
# layers.29.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0125,  0.0252,  0.0107,  ..., -0.0302, -0.0077,  0.0101],
#         [-0.0166,  0.0369, -0.0016,  ...,  0.0102, -0.0002,  0.0278],
#         [ 0.0371, -0.0064, -0.0255,  ..., -0.0167,  0.0123,  0.0212],
#         ...,
#         [ 0.0104,  0.0208, -0.0266,  ...,  0.0114,  0.0362, -0.0345],
#         [-0.0033,  0.0165,  0.0060,  ...,  0.0148, -0.0225, -0.0227],
#         [ 0.0058, -0.0181,  0.0096,  ..., -0.0056,  0.0304,  0.0075]],
#        requires_grad=True)
# layers.29.mlp.down_proj.weight: Parameter containing:
# tensor([[-0.0094,  0.0027, -0.0190,  ..., -0.0041, -0.0053, -0.0151],
#         [-0.0334,  0.0068,  0.0334,  ..., -0.0183, -0.0169,  0.0009],
#         [ 0.0004, -0.0322, -0.0060,  ...,  0.0367,  0.0051,  0.0243],
#         ...,
#         [-0.0131, -0.0213, -0.0185,  ..., -0.0206, -0.0063, -0.0054],
#         [ 0.0327, -0.0147,  0.0119,  ...,  0.0176,  0.0023,  0.0629],
#         [ 0.0093, -0.0044, -0.0435,  ...,  0.0265, -0.0099,  0.0109]],
#        requires_grad=True)
# layers.29.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.29.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.30.self_attn.q_proj.weight: Parameter containing:
# tensor([[-3.0430e-02, -1.8213e-02,  1.3249e-02,  ...,  3.3670e-02,
#           3.7779e-03,  1.2852e-02],
#         [-7.0629e-05,  2.0294e-02, -2.8023e-02,  ...,  1.2038e-02,
#           8.0690e-03, -1.2248e-02],
#         [-2.2401e-02,  1.0279e-02,  2.4147e-02,  ...,  1.0115e-02,
#           1.7382e-02, -3.4787e-03],
#         ...,
#         [ 5.4985e-03, -3.1016e-03, -2.7350e-02,  ..., -3.9638e-03,
#           2.1204e-03,  5.5242e-03],
#         [-1.3585e-02,  6.6060e-03, -4.2086e-02,  ...,  3.9323e-04,
#          -1.5865e-02, -1.7872e-02],
#         [ 1.0715e-02,  1.9645e-02, -4.2506e-03,  ..., -2.2867e-04,
#           1.4258e-02, -2.0350e-02]], requires_grad=True)
# layers.30.self_attn.k_proj.weight: Parameter containing:
# tensor([[ 0.0157,  0.0028,  0.0158,  ...,  0.0128,  0.0129, -0.0012],
#         [-0.0010, -0.0265, -0.0038,  ...,  0.0370, -0.0372,  0.0013],
#         [ 0.0213, -0.0286,  0.0097,  ...,  0.0035,  0.0057, -0.0155],
#         ...,
#         [-0.0222,  0.0144, -0.0056,  ..., -0.0218, -0.0183,  0.0184],
#         [-0.0245, -0.0062,  0.0107,  ...,  0.0197,  0.0347,  0.0179],
#         [ 0.0198,  0.0126,  0.0154,  ...,  0.0249, -0.0386, -0.0104]],
#        requires_grad=True)
# layers.30.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 2.8785e-02,  5.1861e-02, -1.4682e-02,  ..., -2.6648e-02,
#          -8.0652e-03,  2.5485e-02],
#         [ 3.2411e-02, -2.7663e-03, -1.6197e-02,  ..., -1.6831e-02,
#          -8.4227e-03,  1.6733e-02],
#         [-4.2314e-03,  8.2505e-03,  9.1328e-03,  ..., -1.7296e-02,
#           5.9523e-03,  2.3025e-02],
#         ...,
#         [ 1.7505e-02,  3.8581e-02, -1.9588e-02,  ...,  4.9035e-03,
#           1.1038e-02,  2.3699e-02],
#         [ 1.0150e-05,  1.4564e-02,  2.5074e-02,  ...,  1.3491e-02,
#          -2.2844e-02, -2.3797e-02],
#         [ 3.0253e-02, -4.7906e-04, -1.5154e-02,  ...,  3.5319e-02,
#           2.9957e-02,  7.3224e-03]], requires_grad=True)
# layers.30.self_attn.o_proj.weight: Parameter containing:
# tensor([[-0.0145,  0.0244,  0.0156,  ..., -0.0013,  0.0101, -0.0128],
#         [-0.0276,  0.0347, -0.0308,  ...,  0.0047, -0.0092,  0.0028],
#         [-0.0234,  0.0185,  0.0266,  ...,  0.0120,  0.0127,  0.0322],
#         ...,
#         [ 0.0066, -0.0035,  0.0012,  ...,  0.0112,  0.0118,  0.0178],
#         [-0.0182, -0.0203,  0.0410,  ...,  0.0022,  0.0192,  0.0068],
#         [ 0.0011,  0.0099, -0.0404,  ..., -0.0495,  0.0357,  0.0029]],
#        requires_grad=True)
# layers.30.mlp.gate_proj.weight: Parameter containing:
# tensor([[ 0.0020,  0.0354, -0.0228,  ..., -0.0243,  0.0466, -0.0268],
#         [-0.0116, -0.0086, -0.0202,  ...,  0.0292, -0.0035, -0.0400],
#         [-0.0176,  0.0290,  0.0108,  ..., -0.0168,  0.0119,  0.0250],
#         ...,
#         [ 0.0054, -0.0127,  0.0054,  ..., -0.0171,  0.0028, -0.0091],
#         [-0.0005, -0.0151, -0.0211,  ..., -0.0090, -0.0210, -0.0130],
#         [-0.0142, -0.0133, -0.0060,  ...,  0.0266, -0.0275,  0.0072]],
#        requires_grad=True)
# layers.30.mlp.up_proj.weight: Parameter containing:
# tensor([[-1.6037e-02,  9.6145e-03,  2.8542e-03,  ..., -5.2208e-03,
#           7.9429e-03, -1.6029e-02],
#         [ 2.3129e-02, -1.1542e-02, -3.3313e-02,  ...,  5.3963e-04,
#           3.0369e-02, -1.8613e-05],
#         [ 1.1160e-02, -1.0444e-02, -1.0135e-02,  ..., -1.1947e-02,
#          -2.0110e-02,  1.0630e-02],
#         ...,
#         [ 2.1935e-02, -4.2562e-02,  1.7064e-02,  ...,  2.2911e-02,
#          -1.2647e-03, -3.2018e-02],
#         [-3.0354e-02,  1.5838e-02,  2.9689e-04,  ...,  2.8325e-03,
#           4.8048e-03, -5.7854e-03],
#         [ 9.1566e-03,  1.2116e-02,  1.0866e-02,  ...,  2.6298e-02,
#          -3.3089e-03, -3.5867e-02]], requires_grad=True)
# layers.30.mlp.down_proj.weight: Parameter containing:
# tensor([[ 0.0312, -0.0016, -0.0042,  ...,  0.0126,  0.0033,  0.0135],
#         [ 0.0196,  0.0074, -0.0137,  ..., -0.0007, -0.0029,  0.0058],
#         [ 0.0151,  0.0178, -0.0162,  ...,  0.0077, -0.0186, -0.0093],
#         ...,
#         [-0.0042,  0.0053, -0.0386,  ..., -0.0132,  0.0020,  0.0201],
#         [-0.0161, -0.0037,  0.0039,  ..., -0.0050,  0.0249, -0.0192],
#         [ 0.0320,  0.0376,  0.0090,  ..., -0.0270, -0.0027,  0.0146]],
#        requires_grad=True)
# layers.30.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.30.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.31.self_attn.q_proj.weight: Parameter containing:
# tensor([[-0.0020, -0.0067, -0.0101,  ...,  0.0146, -0.0239,  0.0321],
#         [ 0.0135,  0.0040, -0.0069,  ...,  0.0004,  0.0082,  0.0312],
#         [ 0.0103, -0.0276,  0.0159,  ..., -0.0064,  0.0093, -0.0120],
#         ...,
#         [-0.0165,  0.0366, -0.0079,  ..., -0.0032,  0.0464,  0.0008],
#         [ 0.0414, -0.0045, -0.0295,  ...,  0.0005,  0.0012,  0.0222],
#         [-0.0308,  0.0259,  0.0593,  ...,  0.0175, -0.0081, -0.0110]],
#        requires_grad=True)
# layers.31.self_attn.k_proj.weight: Parameter containing:
# tensor([[-0.0164, -0.0305,  0.0194,  ..., -0.0107, -0.0059, -0.0093],
#         [ 0.0025,  0.0357, -0.0118,  ...,  0.0208,  0.0160, -0.0058],
#         [-0.0276,  0.0111, -0.0070,  ...,  0.0031, -0.0157,  0.0097],
#         ...,
#         [-0.0141,  0.0405, -0.0286,  ...,  0.0071, -0.0086, -0.0084],
#         [ 0.0010, -0.0016, -0.0126,  ..., -0.0141, -0.0052, -0.0381],
#         [ 0.0125,  0.0215,  0.0158,  ...,  0.0029, -0.0048,  0.0087]],
#        requires_grad=True)
# layers.31.self_attn.v_proj.weight: Parameter containing:
# tensor([[ 2.8419e-02,  6.2829e-03,  1.5766e-02,  ..., -9.4583e-03,
#          -1.1958e-02, -1.4783e-02],
#         [ 1.9948e-02, -4.2981e-02,  8.2983e-04,  ..., -5.1178e-02,
#           1.3560e-02, -2.0739e-03],
#         [-8.5393e-03, -2.2070e-03,  3.0609e-02,  ...,  1.0811e-02,
#          -2.6203e-02, -4.3359e-03],
#         ...,
#         [ 7.9036e-04, -3.9567e-03, -1.5221e-03,  ..., -2.3555e-02,
#          -5.8261e-03, -3.7546e-03],
#         [-4.3750e-02, -3.0285e-02,  4.6106e-02,  ..., -6.5764e-03,
#           5.8042e-03, -6.1587e-03],
#         [ 3.9934e-05, -1.2827e-02, -3.3587e-02,  ...,  2.6930e-02,
#           2.9255e-02,  1.3062e-02]], requires_grad=True)
# layers.31.self_attn.o_proj.weight: Parameter containing:
# tensor([[-0.0129, -0.0388, -0.0151,  ...,  0.0009, -0.0051,  0.0061],
#         [ 0.0279,  0.0022, -0.0161,  ..., -0.0114,  0.0001, -0.0104],
#         [ 0.0299, -0.0013, -0.0019,  ..., -0.0205,  0.0182,  0.0455],
#         ...,
#         [ 0.0188,  0.0005, -0.0039,  ..., -0.0035, -0.0145,  0.0170],
#         [ 0.0096,  0.0214, -0.0131,  ..., -0.0044, -0.0151, -0.0003],
#         [ 0.0294,  0.0166, -0.0180,  ...,  0.0214,  0.0397,  0.0023]],
#        requires_grad=True)
# layers.31.mlp.gate_proj.weight: Parameter containing:
# tensor([[-9.7256e-03,  1.8029e-02, -6.2049e-03,  ...,  2.1824e-02,
#          -3.0940e-03, -1.9305e-02],
#         [ 2.8443e-02, -3.3778e-04,  1.1868e-02,  ..., -1.9015e-02,
#          -2.0794e-02, -9.8315e-03],
#         [ 9.3994e-03, -2.2604e-02, -1.6815e-02,  ...,  3.9643e-02,
#          -1.4699e-02,  3.8854e-03],
#         ...,
#         [ 1.5547e-02, -5.3305e-03, -3.9469e-03,  ..., -3.1128e-02,
#           4.7031e-02, -3.8726e-03],
#         [ 5.6594e-03, -3.2767e-02,  3.9015e-03,  ..., -1.9562e-02,
#          -6.2417e-03,  9.7554e-03],
#         [-1.4179e-02,  1.3859e-05, -2.5363e-02,  ..., -3.4274e-02,
#          -4.9621e-03,  2.7631e-02]], requires_grad=True)
# layers.31.mlp.up_proj.weight: Parameter containing:
# tensor([[-0.0016,  0.0101, -0.0176,  ..., -0.0149, -0.0008, -0.0222],
#         [ 0.0113,  0.0100, -0.0301,  ...,  0.0089, -0.0060, -0.0011],
#         [-0.0509, -0.0203, -0.0289,  ..., -0.0015,  0.0159,  0.0118],
#         ...,
#         [ 0.0185,  0.0033,  0.0048,  ...,  0.0191,  0.0126,  0.0142],
#         [-0.0016, -0.0137, -0.0156,  ..., -0.0088,  0.0438, -0.0036],
#         [-0.0238, -0.0091,  0.0366,  ...,  0.0073, -0.0232, -0.0277]],
#        requires_grad=True)
# layers.31.mlp.down_proj.weight: Parameter containing:
# tensor([[-1.1986e-02,  1.5578e-02,  1.9098e-02,  ..., -1.2904e-02,
#          -4.2616e-03, -1.0948e-02],
#         [-6.5548e-03, -1.3730e-02,  1.2687e-02,  ...,  1.1079e-02,
#          -1.1769e-05,  2.7228e-02],
#         [ 6.4392e-03, -1.7619e-03, -2.4789e-03,  ...,  1.9212e-02,
#          -2.6641e-02,  8.2338e-03],
#         ...,
#         [ 1.8534e-02, -1.0316e-02,  2.5657e-02,  ...,  5.9614e-03,
#          -6.3144e-03, -1.2498e-02],
#         [-6.2362e-06, -1.7808e-02,  8.4258e-03,  ..., -1.2163e-02,
#          -3.1746e-02,  1.0491e-02],
#         [ 1.3101e-02,  2.5138e-02,  2.6845e-02,  ..., -2.6975e-04,
#           8.8636e-04, -6.8065e-03]], requires_grad=True)
# layers.31.input_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# layers.31.post_attention_layernorm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
# norm.weight: Parameter containing:
# tensor([1., 1., 1.,  ..., 1., 1., 1.], requires_grad=True)
